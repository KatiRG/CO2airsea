# %%
#Script to reformat flux xls file for use in a stacked bar chart

#Created: 12.04.2016
#Last modified:

# %%
import numpy as np
import pandas as pd
import collections
import os
import xlrd

# %%
# Create dataframe from flux file

xl = pd.ExcelFile("/homel/cnangini/PROJECTS/CO2airsea/for_DataViz.xls")
xl.sheet_names
#[u'Sheet1', u'Sheet2', u'Sheet3']
#[u'Sheet1']
df = xl.parse("Sheet1")
df.head(10)
# Out:
#    Unnamed: 0                    Unnamed: 1      Unnamed: 2  \
# 0         NaN  Laruelle et al. (2013, 2014)             NaN
# 1         NaN                       MARCATS           CLASS
# 2         NaN            California Current             EBC
# 3         NaN    Peruvian Upwelling Current             EBC
# 4         NaN             Iberian Upwelling             EBC
# 5         NaN            Moroccan Upwelling             EBC
# 6         NaN       Southern Western Africa             EBC
# 7         NaN               Leeuwin Current             EBC
# 8         NaN           Western Arabian Sea  Indian margins
# 9         NaN           Eastern Arabian Sea  Indian margins
#
#            Unnamed: 3                 ORCA2                        Unnamed: 5  \
# 0                 NaN  Surface\n(10^3 km^2)  Air-sea flux\n(mol C m^-2 yr^-1)
# 1  Mean Latitude (°N)                   NaN                             Total
# 2               31.43               71.9735                          0.258775
# 3              -20.98               130.317                        -0.0424662
# 4               47.39               174.844                         -0.953769
# 5               22.46               111.796                          0.192162
# 6              -27.99               307.138                          -1.14521
# 7              -28.21               38.0426                         -0.909239
# 8               17.08               20.4899                         -0.062801
# 9               16.61               340.797                            0.1413
#
#       Unnamed: 6                ORCA05                        Unnamed: 8  \
# 0            NaN  Surface\n(10^3 km^2)  Air-sea flux\n(mol C m^-2 yr^-1)
# 1  Anthropogenic                   NaN                             Total
# 2            NaN               118.311                          -0.33556
# 3            NaN               137.516                           1.44461
# 4            NaN               251.093                          -1.12506
# 5            NaN               176.947                           0.18122
# 6            NaN               299.792                          0.428844
# 7            NaN               81.4649                          -2.05471
# 8            NaN               81.8175                          0.347792
# 9            NaN                 323.5                          0.209194
#
#       Unnamed: 9               ORCA025                       Unnamed: 11  \
# 0            NaN  Surface\n(10^3 km^2)  Air-sea flux\n(mol C m^-2 yr^-1)
# 1  Anthropogenic                   NaN                             Total
# 2          -0.35               197.109                         -0.408655
# 3          -0.39               143.984                           1.40228
# 4          -0.27               278.965                         -0.850057
# 5          -0.33               210.894                          0.201397
# 6          -0.59               306.152                          0.413103
# 7           -0.6               110.191                           -1.8733
# 8          -0.31               104.031                          0.470945
# 9           -0.3               355.181                          0.285837
#
#      Unnamed: 12
# 0            NaN
# 1  Anthropogenic
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %%
df05 = df.drop(['Unnamed: 0', 'ORCA2', 'Unnamed: 5', 'Unnamed: 6', 'ORCA025', 'Unnamed: 11', 'Unnamed: 12'], 1)
#rename columns
df05.columns = ['MARCATS', 'RCLASS', 'LAT', 'AREA', 'TOTAL', 'ANTHRO']
df05.head(5)
# Out:
#                         MARCATS RCLASS                 LAT  \
# 0  Laruelle et al. (2013, 2014)    NaN                 NaN
# 1                       MARCATS  CLASS  Mean Latitude (°N)
# 2            California Current    EBC               31.43
# 3    Peruvian Upwelling Current    EBC              -20.98
# 4             Iberian Upwelling    EBC               47.39
#
#                    AREA                             TOTAL         ANTHRO
# 0  Surface\n(10^3 km^2)  Air-sea flux\n(mol C m^-2 yr^-1)            NaN
# 1                   NaN                             Total  Anthropogenic
# 2               118.311                          -0.33556          -0.35
# 3               137.516                           1.44461          -0.39
# 4               251.093                          -1.12506          -0.27

# %%
#Remove rows 0 and 1
df05 = df05.drop([0, 1], 0)
df05.head(5)
# Out:
#                       MARCATS RCLASS    LAT     AREA     TOTAL ANTHRO
# 2          California Current    EBC  31.43  118.311  -0.33556  -0.35
# 3  Peruvian Upwelling Current    EBC -20.98  137.516   1.44461  -0.39
# 4           Iberian Upwelling    EBC  47.39  251.093  -1.12506  -0.27
# 5          Moroccan Upwelling    EBC  22.46  176.947   0.18122  -0.33
# 6     Southern Western Africa    EBC -27.99  299.792  0.428844  -0.59

# %%
#Add column for abs value of ANTRHO for plotting purposes
df05['abs_anthro'] = -1 * df05['ANTHRO']
df05.head(5)
# Out:
#                       MARCATS RCLASS    LAT     AREA     TOTAL ANTHRO  \
# 2          California Current    EBC  31.43  118.311  -0.33556  -0.35
# 3  Peruvian Upwelling Current    EBC -20.98  137.516   1.44461  -0.39
# 4           Iberian Upwelling    EBC  47.39  251.093  -1.12506  -0.27
# 5          Moroccan Upwelling    EBC  22.46  176.947   0.18122  -0.33
# 6     Southern Western Africa    EBC -27.99  299.792  0.428844  -0.59
#
#   abs_anthro
# 2       0.35
# 3       0.39
# 4       0.27
# 5       0.33
# 6       0.59

# %%
#Add columns normalized by surface area

df05['total_perArea'] = df05['TOTAL']/df05['AREA']
df05['anthro_perArea'] = df05['ANTHRO']/df05['AREA']
df05.head(5)
# Out:
#                       MARCATS RCLASS    LAT     AREA     TOTAL ANTHRO  \
# 2          California Current    EBC  31.43  118.311  -0.33556  -0.35
# 3  Peruvian Upwelling Current    EBC -20.98  137.516   1.44461  -0.39
# 4           Iberian Upwelling    EBC  47.39  251.093  -1.12506  -0.27
# 5          Moroccan Upwelling    EBC  22.46  176.947   0.18122  -0.33
# 6     Southern Western Africa    EBC -27.99  299.792  0.428844  -0.59
#
#   abs_anthro total_perArea anthro_perArea
# 2       0.35  -0.002836254   -0.002958305
# 3       0.39    0.01050503   -0.002836034
# 4       0.27  -0.004480651   -0.001075299
# 5       0.33   0.001024148   -0.001864965
# 6       0.59   0.001430472   -0.001968031

# %%
#http://stackoverflow.com/questions/29942167/transposing-one-column-in-python-pandas-with-the-simplest-index-possible
#dc.pivot(columns='disease_header', index='medicine', values='disease').reset_index()
df05_piv = df05.pivot(columns='MARCATS', index='RCLASS', values='abs_anthro').reset_index()
#df05_piv = df05_piv.drop(['CLASS'], 1)
df05_piv
# Out:
# MARCATS          RCLASS Agulhas Current Antarctic Shelves Baltic Sea  \
# 0                   EBC             NaN               NaN        NaN
# 1        Indian margins             NaN               NaN        NaN
# 2          Marginal sea             NaN               NaN       0.01
# 3                 Polar             NaN              0.69        NaN
# 4              Subpolar             NaN               NaN        NaN
# 5              Tropical             NaN               NaN        NaN
# 6                   WBC            0.53               NaN        NaN
#
# MARCATS Barents & Kara Sea Bay of Bengal Black Sea Brazilian Current  \
# 0                      NaN           NaN       NaN               NaN
# 1                      NaN          0.31       NaN               NaN
# 2                      NaN           NaN      0.18               NaN
# 3                     0.11           NaN       NaN               NaN
# 4                      NaN           NaN       NaN               NaN
# 5                      NaN           NaN       NaN               NaN
# 6                      NaN           NaN       NaN              0.34
#
# MARCATS California Current Canadian Archipeloagos         ...          \
# 0                     0.35                    NaN         ...
# 1                      NaN                    NaN         ...
# 2                      NaN                    NaN         ...
# 3                      NaN                   0.09         ...
# 4                      NaN                    NaN         ...
# 5                      NaN                    NaN         ...
# 6                      NaN                    NaN         ...
#
# MARCATS Southern America Southern Australia Southern Greenland  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN               0.86
# 4                   0.46               0.27                NaN
# 5                    NaN                NaN                NaN
# 6                    NaN                NaN                NaN
#
# MARCATS Southern Western Africa Tropical Eastern Atlantic  \
# 0                          0.59                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# 5                           NaN                      0.19
# 6                           NaN                       NaN
#
# MARCATS Tropical Eastern Indian Tropical Eastern Pacific  \
# 0                           NaN                      NaN
# 1                           0.2                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# 5                           NaN                     0.36
# 6                           NaN                      NaN
#
# MARCATS Tropical Western Atlantic Tropical Western Indian Western Arabian Sea
# 0                             NaN                     NaN                 NaN
# 1                             NaN                     NaN                0.31
# 2                             NaN                     NaN                 NaN
# 3                             NaN                     NaN                 NaN
# 4                             NaN                     NaN                 NaN
# 5                            0.26                    0.16                 NaN
# 6                             NaN                     NaN                 NaN
#
# [7 rows x 46 columns]

# %%
#Get class list
class_list = np.unique(df05.iloc[:,1].values)
class_list
# Out:
# array([u'EBC', u'Indian margins', u'Marginal sea', u'Polar', u'Subpolar',
#        u'Tropical', u'WBC'], dtype=object)

# %%
df05_piv['RCLASS'] = class_list
df05_piv
# Out:
# MARCATS          RCLASS Agulhas Current Antarctic Shelves Baltic Sea  \
# 0                   EBC             NaN               NaN        NaN
# 1        Indian margins             NaN               NaN        NaN
# 2          Marginal sea             NaN               NaN       0.01
# 3                 Polar             NaN              0.69        NaN
# 4              Subpolar             NaN               NaN        NaN
# 5              Tropical             NaN               NaN        NaN
# 6                   WBC            0.53               NaN        NaN
#
# MARCATS Barents & Kara Sea Bay of Bengal Black Sea Brazilian Current  \
# 0                      NaN           NaN       NaN               NaN
# 1                      NaN          0.31       NaN               NaN
# 2                      NaN           NaN      0.18               NaN
# 3                     0.11           NaN       NaN               NaN
# 4                      NaN           NaN       NaN               NaN
# 5                      NaN           NaN       NaN               NaN
# 6                      NaN           NaN       NaN              0.34
#
# MARCATS California Current Canadian Archipeloagos         ...          \
# 0                     0.35                    NaN         ...
# 1                      NaN                    NaN         ...
# 2                      NaN                    NaN         ...
# 3                      NaN                   0.09         ...
# 4                      NaN                    NaN         ...
# 5                      NaN                    NaN         ...
# 6                      NaN                    NaN         ...
#
# MARCATS Southern America Southern Australia Southern Greenland  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN               0.86
# 4                   0.46               0.27                NaN
# 5                    NaN                NaN                NaN
# 6                    NaN                NaN                NaN
#
# MARCATS Southern Western Africa Tropical Eastern Atlantic  \
# 0                          0.59                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# 5                           NaN                      0.19
# 6                           NaN                       NaN
#
# MARCATS Tropical Eastern Indian Tropical Eastern Pacific  \
# 0                           NaN                      NaN
# 1                           0.2                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# 5                           NaN                     0.36
# 6                           NaN                      NaN
#
# MARCATS Tropical Western Atlantic Tropical Western Indian Western Arabian Sea
# 0                             NaN                     NaN                 NaN
# 1                             NaN                     NaN                0.31
# 2                             NaN                     NaN                 NaN
# 3                             NaN                     NaN                 NaN
# 4                             NaN                     NaN                 NaN
# 5                            0.26                    0.16                 NaN
# 6                             NaN                     NaN                 NaN
#
# [7 rows x 46 columns]

# %%
df05_piv.columns.name
# Out:
# 'MARCATS'

# %%
df05_piv.columns.name = ''
df05_piv
# Out:
#            RCLASS Agulhas Current Antarctic Shelves Baltic Sea  \
# 0             EBC             NaN               NaN        NaN
# 1  Indian margins             NaN               NaN        NaN
# 2    Marginal sea             NaN               NaN       0.01
# 3           Polar             NaN              0.69        NaN
# 4        Subpolar             NaN               NaN        NaN
# 5        Tropical             NaN               NaN        NaN
# 6             WBC            0.53               NaN        NaN
#
#   Barents & Kara Sea Bay of Bengal Black Sea Brazilian Current  \
# 0                NaN           NaN       NaN               NaN
# 1                NaN          0.31       NaN               NaN
# 2                NaN           NaN      0.18               NaN
# 3               0.11           NaN       NaN               NaN
# 4                NaN           NaN       NaN               NaN
# 5                NaN           NaN       NaN               NaN
# 6                NaN           NaN       NaN              0.34
#
#   California Current Canadian Archipeloagos         ...          \
# 0               0.35                    NaN         ...
# 1                NaN                    NaN         ...
# 2                NaN                    NaN         ...
# 3                NaN                   0.09         ...
# 4                NaN                    NaN         ...
# 5                NaN                    NaN         ...
# 6                NaN                    NaN         ...
#
#   Southern America Southern Australia Southern Greenland  \
# 0              NaN                NaN                NaN
# 1              NaN                NaN                NaN
# 2              NaN                NaN                NaN
# 3              NaN                NaN               0.86
# 4             0.46               0.27                NaN
# 5              NaN                NaN                NaN
# 6              NaN                NaN                NaN
#
#   Southern Western Africa Tropical Eastern Atlantic Tropical Eastern Indian  \
# 0                    0.59                       NaN                     NaN
# 1                     NaN                       NaN                     0.2
# 2                     NaN                       NaN                     NaN
# 3                     NaN                       NaN                     NaN
# 4                     NaN                       NaN                     NaN
# 5                     NaN                      0.19                     NaN
# 6                     NaN                       NaN                     NaN
#
#   Tropical Eastern Pacific Tropical Western Atlantic Tropical Western Indian  \
# 0                      NaN                       NaN                     NaN
# 1                      NaN                       NaN                     NaN
# 2                      NaN                       NaN                     NaN
# 3                      NaN                       NaN                     NaN
# 4                      NaN                       NaN                     NaN
# 5                     0.36                      0.26                    0.16
# 6                      NaN                       NaN                     NaN
#
#   Western Arabian Sea
# 0                 NaN
# 1                0.31
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
#
# [7 rows x 46 columns]

# %%
#Replace NaN with blank space
df05_piv = df05_piv.replace(np.nan,0, regex=True)
df05_piv
# Out:
#            RCLASS  Agulhas Current  Antarctic Shelves  Baltic Sea  \
# 0             EBC             0.00               0.00        0.00
# 1  Indian margins             0.00               0.00        0.00
# 2    Marginal sea             0.00               0.00        0.01
# 3           Polar             0.00               0.69        0.00
# 4        Subpolar             0.00               0.00        0.00
# 5        Tropical             0.00               0.00        0.00
# 6             WBC             0.53               0.00        0.00
#
#    Barents & Kara Sea  Bay of Bengal  Black Sea  Brazilian Current  \
# 0                0.00           0.00       0.00               0.00
# 1                0.00           0.31       0.00               0.00
# 2                0.00           0.00       0.18               0.00
# 3                0.11           0.00       0.00               0.00
# 4                0.00           0.00       0.00               0.00
# 5                0.00           0.00       0.00               0.00
# 6                0.00           0.00       0.00               0.34
#
#    California Current  Canadian Archipeloagos         ...           \
# 0                0.35                    0.00         ...
# 1                0.00                    0.00         ...
# 2                0.00                    0.00         ...
# 3                0.00                    0.09         ...
# 4                0.00                    0.00         ...
# 5                0.00                    0.00         ...
# 6                0.00                    0.00         ...
#
#    Southern America  Southern Australia  Southern Greenland  \
# 0              0.00                0.00                0.00
# 1              0.00                0.00                0.00
# 2              0.00                0.00                0.00
# 3              0.00                0.00                0.86
# 4              0.46                0.27                0.00
# 5              0.00                0.00                0.00
# 6              0.00                0.00                0.00
#
#    Southern Western Africa  Tropical Eastern Atlantic  \
# 0                     0.59                       0.00
# 1                     0.00                       0.00
# 2                     0.00                       0.00
# 3                     0.00                       0.00
# 4                     0.00                       0.00
# 5                     0.00                       0.19
# 6                     0.00                       0.00
#
#    Tropical Eastern Indian  Tropical Eastern Pacific  \
# 0                      0.0                      0.00
# 1                      0.2                      0.00
# 2                      0.0                      0.00
# 3                      0.0                      0.00
# 4                      0.0                      0.00
# 5                      0.0                      0.36
# 6                      0.0                      0.00
#
#    Tropical Western Atlantic  Tropical Western Indian  Western Arabian Sea
# 0                       0.00                     0.00                 0.00
# 1                       0.00                     0.00                 0.31
# 2                       0.00                     0.00                 0.00
# 3                       0.00                     0.00                 0.00
# 4                       0.00                     0.00                 0.00
# 5                       0.26                     0.16                 0.00
# 6                       0.00                     0.00                 0.00
#
# [7 rows x 46 columns]

# %%
df05_piv.iloc[[0]]
# Out:
#   RCLASS  Agulhas Current  Antarctic Shelves  Baltic Sea  Barents & Kara Sea  \
# 0    EBC                0                  0           0                   0
#
#    Bay of Bengal  Black Sea  Brazilian Current  California Current  \
# 0              0          0                  0                0.35
#
#    Canadian Archipeloagos         ...           Southern America  \
# 0                       0         ...                          0
#
#    Southern Australia  Southern Greenland  Southern Western Africa  \
# 0                   0                   0                     0.59
#
#    Tropical Eastern Atlantic  Tropical Eastern Indian  \
# 0                          0                        0
#
#    Tropical Eastern Pacific  Tropical Western Atlantic  \
# 0                         0                          0
#
#    Tropical Western Indian  Western Arabian Sea
# 0                        0                    0
#
# [1 rows x 46 columns]

# %%
#Save to csv
#df05_piv.to_csv('/homel/cnangini/PROJECTS/CO2airsea/orca05.tsv', float_format='%.2f', sep='\t')

# %%
#Build sankey json file

# %%
dict_files = collections.OrderedDict()
dict_files['EBC'] = 'coal.csv'
dict_files['']='gas.csv'
dict_files['Gas flaring']='flaring.csv'
dict_files['Cement']='cement.csv'
dict_files['Oil']='oil.csv'                
list_fields = ['Africa', 'Asia', 'Central America', 'Europe', 'Middle East', 'North America', 'Oceania', 'South America']
year = 2014

# %%
#Get sources list
sources = np.unique(df05.iloc[:,1].values) #RCLASS COL
sources
# Out:
# [u'EBC',
#  u'Indian margins',
#  u'Marginal sea',
#  u'Polar',
#  u'Subpolar',
#  u'Tropical',
#  u'WBC']

# %%
#Get regions list
regions = np.unique(df05.iloc[:,0].values) #MARCAT col

# %%
nodes = sources.tolist() + regions.tolist()
nodes
# Out:
# [u'EBC',
#  u'Indian margins',
#  u'Marginal sea',
#  u'Polar',
#  u'Subpolar',
#  u'Tropical',
#  u'WBC',
#  u'Agulhas Current',
#  u'Antarctic Shelves',
#  u'Baltic Sea',
#  u'Barents & Kara Sea',
#  u'Bay of Bengal',
#  u'Black Sea',
#  u'Brazilian Current',
#  u'California Current',
#  u'Canadian Archipeloagos',
#  u'Carribean Sea',
#  u'China Sea & Kuroshio',
#  u'Eastern Arabian Sea',
#  u'Eastern Austrialian Current',
#  u'Florida Upwelling',
#  u'Gulf of Mexico',
#  u'Hudson Bay',
#  u'Iberian Upwelling',
#  u'Leeuwin Current',
#  u'Mediterranean Sea',
#  u'Moroccan Upwelling',
#  u'New Zealand',
#  u'North Eastern Atlantic',
#  u'North Eastern Pacific',
#  u'North Western Pacific',
#  u'Northern Australia',
#  u'Northern Greenland',
#  u'Norwegian Basin',
#  u'Persian Gulf',
#  u'Peruvian Upwelling Current',
#  u'Red Sea',
#  u'Sea of Japan',
#  u'Sea of Labrador',
#  u'Sea of Okhotsk',
#  u'Siberian Shelves',
#  u'South East Asia',
#  u'Southern America',
#  u'Southern Australia',
#  u'Southern Greenland',
#  u'Southern Western Africa',
#  u'Tropical Eastern Atlantic',
#  u'Tropical Eastern Indian',
#  u'Tropical Eastern Pacific',
#  u'Tropical Western Atlantic',
#  u'Tropical Western Indian',
#  u'Western Arabian Sea']

# %%
df05.head(5)
# Out:
#                       MARCATS RCLASS    LAT     AREA     TOTAL ANTHRO  \
# 2          California Current    EBC  31.43  118.311  -0.33556  -0.35
# 3  Peruvian Upwelling Current    EBC -20.98  137.516   1.44461  -0.39
# 4           Iberian Upwelling    EBC  47.39  251.093  -1.12506  -0.27
# 5          Moroccan Upwelling    EBC  22.46  176.947   0.18122  -0.33
# 6     Southern Western Africa    EBC -27.99  299.792  0.428844  -0.59
#
#   abs_anthro total_perArea anthro_perArea
# 2       0.35  -0.002836254   -0.002958305
# 3       0.39    0.01050503   -0.002836034
# 4       0.27  -0.004480651   -0.001075299
# 5       0.33   0.001024148   -0.001864965
# 6       0.59   0.001430472   -0.001968031

# %%
#df05.iloc['California Current']
df05.iloc[0]['abs_anthro']
# Out:
# 0.35

# %%
pwd
# Out:
# u'/home/users/cnangini/IPy_Notebooks'

# %%
sources
# Out:
# array([u'EBC', u'Indian margins', u'Marginal sea', u'Polar', u'Subpolar',
#        u'Tropical', u'WBC'], dtype=object)

# %%
df05
# Out:
#                         MARCATS          RCLASS    LAT     AREA      TOTAL  \
# 2            California Current             EBC  31.43  118.311   -0.33556
# 3    Peruvian Upwelling Current             EBC -20.98  137.516    1.44461
# 4             Iberian Upwelling             EBC  47.39  251.093   -1.12506
# 5            Moroccan Upwelling             EBC  22.46  176.947    0.18122
# 6       Southern Western Africa             EBC -27.99  299.792   0.428844
# 7               Leeuwin Current             EBC -28.21  81.4649   -2.05471
# 8           Western Arabian Sea  Indian margins  17.08  81.8175   0.347792
# 9           Eastern Arabian Sea  Indian margins  16.61    323.5   0.209194
# 10                Bay of Bengal  Indian margins   18.3  197.021  -0.693303
# 11      Tropical Eastern Indian  Indian margins -3.274  726.646 -0.0552213
# 12               Gulf of Mexico    Marginal sea  25.38  469.398  -0.794206
# 13                   Hudson Bay    Marginal sea  60.92  998.314   0.313345
# 14       North Eastern Atlantic    Marginal sea  56.69  1020.02   -2.16314
# 15                   Baltic Sea    Marginal sea  58.98  324.209   0.303937
# 16            Mediterranean Sea    Marginal sea  38.07    423.1    -0.2353
# 17                    Black Sea    Marginal sea  44.75  130.532  -0.239324
# 18                      Red Sea    Marginal sea  18.31  157.725   0.242964
# 19                 Persian Gulf    Marginal sea   26.9  207.628  0.0369855
# 20                 Sea of Japan    Marginal sea  41.93  233.304   -3.07354
# 21               Sea of Okhotsk    Marginal sea  55.61  932.861   -1.66217
# 22       Canadian Archipeloagos           Polar  73.52   1035.1  -0.518609
# 23           Northern Greenland           Polar   75.2  544.174  -0.968926
# 24           Southern Greenland           Polar  64.75   237.64   -3.35089
# 25              Norwegian Basin           Polar  67.94  140.691   -2.87327
# 26             Siberian Shelves           Polar  74.05  1848.21   -0.47295
# 27           Barents & Kara Sea           Polar  74.52   1658.8  -0.748089
# 28            Antarctic Shelves           Polar -71.76     2462  -0.904177
# 29        North Eastern Pacific        Subpolar  56.05  396.824    -2.2943
# 30             Southern America        Subpolar -47.92  1126.28    -1.5125
# 31              Sea of Labrador        Subpolar  58.29  336.267  -0.944395
# 32           Southern Australia        Subpolar  -35.6  391.948   -1.36748
# 33                  New Zealand        Subpolar -45.15  262.966   -1.22903
# 34        North Western Pacific        Subpolar  60.17  1024.93   -1.84886
# 35     Tropical Eastern Pacific        Tropical  8.378  152.319  -0.121617
# 36    Tropical Western Atlantic        Tropical  2.726  478.933   0.857785
# 37                Carribean Sea        Tropical  14.19    303.5     0.1004
# 38    Tropical Eastern Atlantic        Tropical  2.095  225.243  0.0884754
# 39      Tropical Western Indian        Tropical  -13.9  46.4441 -0.0559819
# 40           Northern Australia        Tropical -11.15  2278.28  -0.287668
# 41              South East Asia        Tropical  8.667  2129.62  -0.287109
# 42            Brazilian Current             WBC -27.06  474.457  -0.328442
# 43            Florida Upwelling             WBC  40.62  784.725   -2.08861
# 44              Agulhas Current             WBC -28.37  189.285   -1.20098
# 45  Eastern Austrialian Current             WBC -38.11  97.4527   -1.73964
# 46         China Sea & Kuroshio             WBC  33.13  1131.67    -1.9898
#
#    ANTHRO abs_anthro total_perArea anthro_perArea
# 2   -0.35       0.35  -0.002836254   -0.002958305
# 3   -0.39       0.39    0.01050503   -0.002836034
# 4   -0.27       0.27  -0.004480651   -0.001075299
# 5   -0.33       0.33   0.001024148   -0.001864965
# 6   -0.59       0.59   0.001430472   -0.001968031
# 7    -0.6        0.6   -0.02522203   -0.007365135
# 8   -0.31       0.31   0.004250827    -0.00378892
# 9    -0.3        0.3  0.0006466584   -0.000927357
# 10  -0.31       0.31  -0.003518929   -0.001573436
# 11   -0.2        0.2 -7.599478e-05  -0.0002752372
# 12  -0.32       0.32  -0.001691967  -0.0006817243
# 13  -0.08       0.08  0.0003138742  -8.013511e-05
# 14  -0.53       0.53  -0.002120684  -0.0005195977
# 15  -0.01       0.01  0.0009374724   -3.08443e-05
# 16   -0.3        0.3 -0.0005561333  -0.0007090522
# 17  -0.18       0.18  -0.001833451   -0.001378972
# 18  -0.15       0.15   0.001540428  -0.0009510223
# 19  -0.12       0.12  0.0001781335  -0.0005779567
# 20  -0.51       0.51   -0.01317397   -0.002185989
# 21  -0.36       0.36  -0.001781798  -0.0003859096
# 22  -0.09       0.09 -0.0005010231  -8.694812e-05
# 23  -0.26       0.26  -0.001780544  -0.0004777884
# 24  -0.86       0.86    -0.0141007   -0.003618919
# 25   -0.6        0.6   -0.02042256   -0.004264665
# 26  -0.05       0.05 -0.0002558962   -2.70532e-05
# 27  -0.11       0.11  -0.000450982    -6.6313e-05
# 28  -0.69       0.69  -0.000367253    -0.00028026
# 29  -0.45       0.45  -0.005781656   -0.001134004
# 30  -0.46       0.46  -0.001342917  -0.0004084242
# 31  -0.31       0.31  -0.002808468  -0.0009218865
# 32  -0.27       0.27  -0.003488932  -0.0006888669
# 33  -0.52       0.52  -0.004673722   -0.001977442
# 34  -0.24       0.24  -0.001803889  -0.0002341623
# 35  -0.36       0.36 -0.0007984362   -0.002363461
# 36  -0.26       0.26   0.001791033  -0.0005428734
# 37  -0.31       0.31  0.0003308072   -0.001021417
# 38  -0.19       0.19  0.0003927998  -0.0008435334
# 39  -0.16       0.16  -0.001205361   -0.003445002
# 40  -0.23       0.23 -0.0001262654  -0.0001009534
# 41   -0.2        0.2  -0.000134817  -9.391347e-05
# 42  -0.34       0.34 -0.0006922482  -0.0007166087
# 43  -0.56       0.56  -0.002661582  -0.0007136258
# 44  -0.53       0.53  -0.006344824   -0.002800011
# 45   -0.5        0.5   -0.01785112   -0.005130694
# 46  -0.45       0.45  -0.001758286  -0.0003976424

# %%
file = open('sankey_flux.json', 'w')

file.write('{\n')
file.write('"nodes": [\n')
for node in nodes:
    file.write('{"name": "%s"},\n' %(node))
# remove last comma
file.seek(-2, os.SEEK_END)
file.truncate()
file.write('\n],\n')

file.write('"links": [\n')
idx = 0;
#for source in sources:
for region in regions:
    source = df05.iloc[idx]['RCLASS']
    #for region in regions:
    print idx
    print source
    print region
    #file.write('{"source": "%s", "target": "%s", "value": "%.2f"},\n' %(source, region, df05[region][source]))
    file.write('{"source": "%s", "target": "%s", "value": "%.2f"},\n' %(source, region, df05.iloc[idx]['abs_anthro']))
    idx = idx + 1
# remove last comma
file.seek(-2, os.SEEK_END)
file.truncate()
file.write('\n]\n')
file.write('}\n')

file.close()
# Out:
# 0
# EBC
# Agulhas Current
# 1
# EBC
# Antarctic Shelves
# 2
# EBC
# Baltic Sea
# 3
# EBC
# Barents & Kara Sea
# 4
# EBC
# Bay of Bengal
# 5
# EBC
# Black Sea
# 6
# Indian margins
# Brazilian Current
# 7
# Indian margins
# California Current
# 8
# Indian margins
# Canadian Archipeloagos
# 9
# Indian margins
# Carribean Sea
# 10
# Marginal sea
# China Sea & Kuroshio
# 11
# Marginal sea
# Eastern Arabian Sea
# 12
# Marginal sea
# Eastern Austrialian Current
# 13
# Marginal sea
# Florida Upwelling
# 14
# Marginal sea
# Gulf of Mexico
# 15
# Marginal sea
# Hudson Bay
# 16
# Marginal sea
# Iberian Upwelling
# 17
# Marginal sea
# Leeuwin Current
# 18
# Marginal sea
# Mediterranean Sea
# 19
# Marginal sea
# Moroccan Upwelling
# 20
# Polar
# New Zealand
# 21
# Polar
# North Eastern Atlantic
# 22
# Polar
# North Eastern Pacific
# 23
# Polar
# North Western Pacific
# 24
# Polar
# Northern Australia
# 25
# Polar
# Northern Greenland
# 26
# Polar
# Norwegian Basin
# 27
# Subpolar
# Persian Gulf
# 28
# Subpolar
# Peruvian Upwelling Current
# 29
# Subpolar
# Red Sea
# 30
# Subpolar
# Sea of Japan
# 31
# Subpolar
# Sea of Labrador
# 32
# Subpolar
# Sea of Okhotsk
# 33
# Tropical
# Siberian Shelves
# 34
# Tropical
# South East Asia
# 35
# Tropical
# Southern America
# 36
# Tropical
# Southern Australia
# 37
# Tropical
# Southern Greenland
# 38
# Tropical
# Southern Western Africa
# 39
# Tropical
# Tropical Eastern Atlantic
# 40
# WBC
# Tropical Eastern Indian
# 41
# WBC
# Tropical Eastern Pacific
# 42
# WBC
# Tropical Western Atlantic
# 43
# WBC
# Tropical Western Indian
# 44
# WBC
# Western Arabian Sea
